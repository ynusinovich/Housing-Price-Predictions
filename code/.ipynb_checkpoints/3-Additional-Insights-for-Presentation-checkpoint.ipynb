# %% [markdown]
# # Project 2 - Ames Housing Data and Kaggle Challenge - Notebook 3
#
# [DSI-US-8 Regression Challenge on Kaggle](https://www.kaggle.com/c/dsi-us-8-project-2-regression-challenge)<br>
# [Data Description](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt)
#
# ---

# %% [markdown]
# ## Contents
# - [Import Libraries](#Import-Libraries)
# - [Load Data](#Load-Data)

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from matplotlib.ticker import FormatStrFormatter, FuncFormatter

from joblib import dump, load

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Load Data

# %%
label_encoder = load("../models/label_encoders_for_nominal_columns.joblib")
lasso_model_best = load("../models/lasso_model_tuned.joblib")
standard_scaler = load("../models/scaler_for_train_data.joblib")

df = pd.read_csv("../datasets/train_clean.csv", dtype = {"Id":str, "PID":str})
df2 = pd.read_csv("../datasets/test_clean.csv", dtype = {"Id":str, "PID":str})
X = df2.drop(['Id', 'PID'], axis = 'columns')
y = lasso_model_best.predict(X)
df2["SalePrice"] = y

# %% [markdown]
# ## Establish Baseline Score

# %%
X_test = df.drop(['Id', 'PID', "SalePrice"], axis = 'columns')
y_test = lasso_model_best.predict(X_test)

# %%
y_avg = df["SalePrice"].mean()
df["AvgPrices"] = y_avg
r2_score(df["SalePrice"], df["AvgPrices"])
# Out:
# 0.0

# %%
r2_score(df["SalePrice"], y_test)
# Out:
# 0.9066615682405196

# %%
df.drop(["AvgPrices"], axis = 1, inplace = True)

# %% [markdown]
# ## Display Label Encodings and Plot Them

# %% [markdown]
# #### Display label encodings and create dictionaries to access them

# %%
columns_to_label_encode = ["MS SubClass",
                           "MS Zoning",
                           "Alley",
                           "Lot Shape",
                           "Land Contour",
                           "Lot Config",
                           "Land Slope",
                           "Neighborhood",
                           "Condition 1",
                           "Condition 2",
                           "Bldg Type",
                           "House Style",
                           "Roof Style",
                           "Roof Matl",
                           "Exterior 1st",
                           "Exterior 2nd",
                           "Mas Vnr Type",
                           "Foundation",
                           "Heating",
                           "Garage Type",
                           "Misc Feature",
                           "Sale Type"]

# %%
for i in range(0,len(label_encoder)):
    print("The label encodings for the",columns_to_label_encode[i],"column are:")
    for j in range(0,len(label_encoder[i].classes_)):
        print(j,"-",label_encoder[i].classes_[j])
# Out:
# The label encodings for the MS SubClass column are:
# 0 - 120
# 1 - 150
# 2 - 160
# 3 - 180
# 4 - 190
# 5 - 20
# 6 - 30
# 7 - 40
# 8 - 45
# 9 - 50
# 10 - 60
# 11 - 70
# 12 - 75
# 13 - 80
# 14 - 85
# 15 - 90
# The label encodings for the MS Zoning column are:
# 0 - A (agr)
# 1 - C (all)
# 2 - FV
# 3 - I (all)
# 4 - RH
# 5 - RL
# 6 - RM
# The label encodings for the Alley column are:
# 0 - Grvl
# 1 - NA
# 2 - Pave
# The label encodings for the Lot Shape column are:
# 0 - IR1
# 1 - IR2
# 2 - IR3
# 3 - Reg
# The label encodings for the Land Contour column are:
# 0 - Bnk
# 1 - HLS
# 2 - Low
# 3 - Lvl
# The label encodings for the Lot Config column are:
# 0 - Corner
# 1 - CulDSac
# 2 - FR2
# 3 - FR3
# 4 - Inside
# The label encodings for the Land Slope column are:
# 0 - Gtl
# 1 - Mod
# 2 - Sev
# The label encodings for the Neighborhood column are:
# 0 - Blmngtn
# 1 - Blueste
# 2 - BrDale
# 3 - BrkSide
# 4 - ClearCr
# 5 - CollgCr
# 6 - Crawfor
# 7 - Edwards
# 8 - Gilbert
# 9 - Greens
# 10 - GrnHill
# 11 - IDOTRR
# 12 - Landmrk
# 13 - MeadowV
# 14 - Mitchel
# 15 - NAmes
# 16 - NPkVill
# 17 - NWAmes
# 18 - NoRidge
# 19 - NridgHt
# 20 - OldTown
# 21 - SWISU
# 22 - Sawyer
# 23 - SawyerW
# 24 - Somerst
# 25 - StoneBr
# 26 - Timber
# 27 - Veenker
# The label encodings for the Condition 1 column are:
# 0 - Artery
# 1 - Feedr
# 2 - Norm
# 3 - PosA
# 4 - PosN
# 5 - RRAe
# 6 - RRAn
# 7 - RRNe
# 8 - RRNn
# The label encodings for the Condition 2 column are:
# 0 - Artery
# 1 - Feedr
# 2 - Norm
# 3 - PosA
# 4 - PosN
# 5 - RRAe
# 6 - RRAn
# 7 - RRNn
# The label encodings for the Bldg Type column are:
# 0 - 1Fam
# 1 - 2fmCon
# 2 - Duplex
# 3 - Twnhs
# 4 - TwnhsE
# The label encodings for the House Style column are:
# 0 - 1.5Fin
# 1 - 1.5Unf
# 2 - 1Story
# 3 - 2.5Fin
# 4 - 2.5Unf
# 5 - 2Story
# 6 - SFoyer
# 7 - SLvl
# The label encodings for the Roof Style column are:
# 0 - Flat
# 1 - Gable
# 2 - Gambrel
# 3 - Hip
# 4 - Mansard
# 5 - Shed
# The label encodings for the Roof Matl column are:
# 0 - CompShg
# 1 - Membran
# 2 - Metal
# 3 - Roll
# 4 - Tar&Grv
# 5 - WdShake
# 6 - WdShngl
# The label encodings for the Exterior 1st column are:
# 0 - AsbShng
# 1 - AsphShn
# 2 - BrkComm
# 3 - BrkFace
# 4 - CBlock
# 5 - CemntBd
# 6 - HdBoard
# 7 - ImStucc
# 8 - MetalSd
# 9 - Other
# 10 - Plywood
# 11 - PreCast
# 12 - Stone
# 13 - Stucco
# 14 - VinylSd
# 15 - Wd Sdng
# 16 - WdShing
# The label encodings for the Exterior 2nd column are:
# 0 - AsbShng
# 1 - AsphShn
# 2 - Brk Cmn
# 3 - BrkFace
# 4 - CBlock
# 5 - CmentBd
# 6 - HdBoard
# 7 - ImStucc
# 8 - MetalSd
# 9 - Other
# 10 - Plywood
# 11 - PreCast
# 12 - Stone
# 13 - Stucco
# 14 - VinylSd
# 15 - Wd Sdng
# 16 - Wd Shng
# The label encodings for the Mas Vnr Type column are:
# 0 - BrkCmn
# 1 - BrkFace
# 2 - CBlock
# 3 - None
# 4 - Stone
# The label encodings for the Foundation column are:
# 0 - BrkTil
# 1 - CBlock
# 2 - PConc
# 3 - Slab
# 4 - Stone
# 5 - Wood
# The label encodings for the Heating column are:
# 0 - Floor
# 1 - GasA
# 2 - GasW
# 3 - Grav
# 4 - OthW
# 5 - Wall
# The label encodings for the Garage Type column are:
# 0 - 2Types
# 1 - Attchd
# 2 - Basment
# 3 - BuiltIn
# 4 - CarPort
# 5 - Detchd
# 6 - NA
# The label encodings for the Misc Feature column are:
# 0 - Gar2
# 1 - NA
# 2 - Othr
# 3 - Shed
# 4 - TenC
# The label encodings for the Sale Type column are:
# 0 - COD
# 1 - CWD
# 2 - Con
# 3 - ConLD
# 4 - ConLI
# 5 - ConLw
# 6 - New
# 7 - Oth
# 8 - VWD
# 9 - WD

# %%
# label_encodings_dict = {}
# for i in range(0,len(columns_to_label_encode)):
#     label_encodings_dict[columns_to_label_encode[i]] = label_encoder[i].classes_.tolist()

label_encodings_dict = {columns_to_label_encode[i]: label_encoder[i].classes_.tolist() for i in range(0,len(columns_to_label_encode))}
label_encodings_dict
# Out:
# {'MS SubClass': ['120',
#   '150',
#   '160',
#   '180',
#   '190',
#   '20',
#   '30',
#   '40',
#   '45',
#   '50',
#   '60',
#   '70',
#   '75',
#   '80',
#   '85',
#   '90'],
#  'MS Zoning': ['A (agr)', 'C (all)', 'FV', 'I (all)', 'RH', 'RL', 'RM'],
#  'Alley': ['Grvl', 'NA', 'Pave'],
#  'Lot Shape': ['IR1', 'IR2', 'IR3', 'Reg'],
#  'Land Contour': ['Bnk', 'HLS', 'Low', 'Lvl'],
#  'Lot Config': ['Corner', 'CulDSac', 'FR2', 'FR3', 'Inside'],
#  'Land Slope': ['Gtl', 'Mod', 'Sev'],
#  'Neighborhood': ['Blmngtn',
#   'Blueste',
#   'BrDale',
#   'BrkSide',
#   'ClearCr',
#   'CollgCr',
#   'Crawfor',
#   'Edwards',
#   'Gilbert',
#   'Greens',
#   'GrnHill',
#   'IDOTRR',
#   'Landmrk',
#   'MeadowV',
#   'Mitchel',
#   'NAmes',
#   'NPkVill',
#   'NWAmes',
#   'NoRidge',
#   'NridgHt',
#   'OldTown',
#   'SWISU',
#   'Sawyer',
#   'SawyerW',
#   'Somerst',
#   'StoneBr',
#   'Timber',
#   'Veenker'],
#  'Condition 1': ['Artery',
#   'Feedr',
#   'Norm',
#   'PosA',
#   'PosN',
#   'RRAe',
#   'RRAn',
#   'RRNe',
#   'RRNn'],
#  'Condition 2': ['Artery',
#   'Feedr',
#   'Norm',
#   'PosA',
#   'PosN',
#   'RRAe',
#   'RRAn',
#   'RRNn'],
#  'Bldg Type': ['1Fam', '2fmCon', 'Duplex', 'Twnhs', 'TwnhsE'],
#  'House Style': ['1.5Fin',
#   '1.5Unf',
#   '1Story',
#   '2.5Fin',
#   '2.5Unf',
#   '2Story',
#   'SFoyer',
#   'SLvl'],
#  'Roof Style': ['Flat', 'Gable', 'Gambrel', 'Hip', 'Mansard', 'Shed'],
#  'Roof Matl': ['CompShg',
#   'Membran',
#   'Metal',
#   'Roll',
#   'Tar&Grv',
#   'WdShake',
#   'WdShngl'],
#  'Exterior 1st': ['AsbShng',
#   'AsphShn',
#   'BrkComm',
#   'BrkFace',
#   'CBlock',
#   'CemntBd',
#   'HdBoard',
#   'ImStucc',
#   'MetalSd',
#   'Other',
#   'Plywood',
#   'PreCast',
#   'Stone',
#   'Stucco',
#   'VinylSd',
#   'Wd Sdng',
#   'WdShing'],
#  'Exterior 2nd': ['AsbShng',
#   'AsphShn',
#   'Brk Cmn',
#   'BrkFace',
#   'CBlock',
#   'CmentBd',
#   'HdBoard',
#   'ImStucc',
#   'MetalSd',
#   'Other',
#   'Plywood',
#   'PreCast',
#   'Stone',
#   'Stucco',
#   'VinylSd',
#   'Wd Sdng',
#   'Wd Shng'],
#  'Mas Vnr Type': ['BrkCmn', 'BrkFace', 'CBlock', 'None', 'Stone'],
#  'Foundation': ['BrkTil', 'CBlock', 'PConc', 'Slab', 'Stone', 'Wood'],
#  'Heating': ['Floor', 'GasA', 'GasW', 'Grav', 'OthW', 'Wall'],
#  'Garage Type': ['2Types',
#   'Attchd',
#   'Basment',
#   'BuiltIn',
#   'CarPort',
#   'Detchd',
#   'NA'],
#  'Misc Feature': ['Gar2', 'NA', 'Othr', 'Shed', 'TenC'],
#  'Sale Type': ['COD',
#   'CWD',
#   'Con',
#   'ConLD',
#   'ConLI',
#   'ConLw',
#   'New',
#   'Oth',
#   'VWD',
#   'WD ']}

# %%
label_encoders_dict = {columns_to_label_encode[i]: label_encoder[i] for i in range(0,len(columns_to_label_encode))}
label_encoders_dict
# Out:
# {'MS SubClass': LabelEncoder(),
#  'MS Zoning': LabelEncoder(),
#  'Alley': LabelEncoder(),
#  'Lot Shape': LabelEncoder(),
#  'Land Contour': LabelEncoder(),
#  'Lot Config': LabelEncoder(),
#  'Land Slope': LabelEncoder(),
#  'Neighborhood': LabelEncoder(),
#  'Condition 1': LabelEncoder(),
#  'Condition 2': LabelEncoder(),
#  'Bldg Type': LabelEncoder(),
#  'House Style': LabelEncoder(),
#  'Roof Style': LabelEncoder(),
#  'Roof Matl': LabelEncoder(),
#  'Exterior 1st': LabelEncoder(),
#  'Exterior 2nd': LabelEncoder(),
#  'Mas Vnr Type': LabelEncoder(),
#  'Foundation': LabelEncoder(),
#  'Heating': LabelEncoder(),
#  'Garage Type': LabelEncoder(),
#  'Misc Feature': LabelEncoder(),
#  'Sale Type': LabelEncoder()}

# %% [markdown]
# #### Plot categorical features to explain their correlations in the presentation

# %%
coeff_series = pd.Series(lasso_model_best.coef_, index = df.columns.drop(["Id","PID","SalePrice"]))
coeff_series.sort_values()
# Out:
# Bedroom AbvGr             -5563.053289
# Bsmt Cond                 -4267.112897
# Kitchen AbvGr             -3774.693734
# Bldg Type                 -3386.899849
# Land Contour              -1662.336031
# House Style               -1609.345833
# Roof Matl                 -1534.671497
# Yr Sold                   -1121.678268
# Pool Combined             -1087.302382
# MS Zoning                  -980.655212
# Exterior Combined          -962.752051
# Electrical                 -825.551243
# Low Qual Fin SF            -795.939851
# Sale Type                  -645.328441
# Lot Shape                  -632.784376
# Central Air                -504.199238
# Alley                      -445.690496
# Heating                    -384.131593
# Fence                      -192.852381
# Misc Val                   -147.824077
# Bsmt Half Bath             -115.922856
# Exter Cond                  -59.569524
# Year Combined                 0.000000
# BsmtFin Type 1                0.000000
# Bsmt Full Bath                0.000000
# Enclosed Porch                0.000000
# Bsmt Unf SF                   0.000000
# MS SubClass                   0.000000
# Year Remod/Add                0.000000
# Open Porch SF                48.551733
# Mo Sold                      63.745346
# Street                      179.801299
# Wood Deck SF                203.975011
# 3Ssn Porch                  322.008869
# Lot Config                  323.994099
# Misc Feature                478.372830
# Neighborhood                517.377548
# Heating QC                  661.272173
# Land Slope                  679.371239
# Condition 2                 722.285992
# Condition 1                 759.410003
# Utilities                   821.000765
# Garage Finish              1138.309762
# Year Remod/Add Squared     1408.627924
# Paved Drive                1482.588052
# Full Bath                  1705.335852
# Lot Frontage               1729.398412
# Half Bath                  1769.626084
# Roof Style                 1844.414908
# Bsmt Type 2 Combined       2545.952623
# Garage Type                2914.826857
# Foundation                 2976.415520
# Screen Porch               3216.601315
# Fireplace Combined         3301.945556
# Functional                 3400.213572
# Bsmt Qual                  3414.945078
# Overall Cond               3951.532621
# Bsmt Exposure              4018.993409
# Mas Vnr Type               4794.175608
# Year Combined Squared      5095.577672
# Kitchen Qual               6001.885170
# Garage Combined            6036.302882
# 2nd Flr SF                 6431.787644
# 1st Flr SF                 6512.224755
# Exter Qual                 6827.005668
# Lot Area                   6991.124352
# Mas Vnr Area               7913.425407
# Total Bsmt SF              8725.410051
# BsmtFin SF 1              10239.517425
# Overall Qual              15628.125780
# Rooms Combined            18625.006947
# dtype: float64

# %% [markdown]
# Which categorical features hurt the value of a home the most in this model?
# - Building type
# - Land contour
# - House style
# - Roof material
# - Zoning
#
# Which categorical features make no difference to the value of a home in this model?
# - Classification of house

# %%
categorical_negative_correlation_columns = ["Bldg Type","Land Contour", "House Style", "Roof Matl", "MS Zoning"]
categorical_no_correlation_columns = ["MS SubClass"]
additional_categorical_columns_to_plot = ["Neighborhood"]

# %%
df_unscaled = df.drop(["Id","PID","SalePrice"], axis = 1)
df_unscaled.loc[:,:] = standard_scaler.inverse_transform(df_unscaled)
df_unscaled["SalePrice"] = df["SalePrice"]
df_unscaled.head()
# Out:
#    MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  Alley  Lot Shape  \
# 0         10.0        5.0      61.89827   13517.0     1.0    1.0        0.0
# 1         10.0        5.0      43.00000   11492.0     1.0    1.0        0.0
# 2          5.0        5.0      68.00000    7922.0     1.0    1.0        3.0
# 3         10.0        5.0      73.00000    9802.0     1.0    1.0        3.0
# 4          9.0        5.0      82.00000   14235.0     1.0    1.0        0.0
#
#    Land Contour  Utilities  Lot Config  Land Slope  Neighborhood  Condition 1  \
# 0           3.0        3.0         1.0         0.0          22.0          5.0
# 1           3.0        3.0         1.0         0.0          23.0          2.0
# 2           3.0        3.0         4.0         0.0          15.0          2.0
# 3           3.0        3.0         4.0         0.0          26.0          2.0
# 4           3.0        3.0         4.0         0.0          23.0          2.0
#
#    Condition 2  Bldg Type  House Style  Overall Qual  Overall Cond  \
# 0          2.0        0.0          5.0           6.0           8.0
# 1          2.0        0.0          5.0           7.0           5.0
# 2          2.0        0.0          2.0           5.0           7.0
# 3          2.0        0.0          5.0           5.0           5.0
# 4          2.0        0.0          0.0           6.0           8.0
#
#    Year Remod/Add  Roof Style  Roof Matl  Mas Vnr Type  Mas Vnr Area  \
# 0          2005.0         1.0        0.0           1.0         289.0
# 1          1997.0         1.0        0.0           1.0         132.0
# 2          2007.0         1.0        0.0           3.0           0.0
# 3          2007.0         1.0        0.0           3.0           0.0
# 4          1993.0         1.0        0.0           3.0           0.0
#
#    Exter Qual  Exter Cond  Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 0         3.0         2.0         1.0        3.0        3.0            1.0
# 1         3.0         2.0         2.0        4.0        3.0            1.0
# 2         2.0         3.0         1.0        3.0        3.0            1.0
# 3         2.0         2.0         2.0        4.0        3.0            1.0
# 4         2.0         2.0         2.0        2.0        4.0            1.0
#
#    BsmtFin Type 1  BsmtFin SF 1  Bsmt Unf SF  Total Bsmt SF  Heating  \
# 0             6.0         533.0        192.0          725.0      1.0
# 1             6.0         637.0        276.0          913.0      1.0
# 2             6.0         731.0        326.0         1057.0      1.0
# 3             1.0           0.0        384.0          384.0      1.0
# 4             1.0           0.0        676.0          676.0      1.0
#
#    Heating QC  Central Air  Electrical  1st Flr SF  2nd Flr SF  \
# 0         4.0          1.0         4.0       725.0       754.0
# 1         4.0          1.0         4.0       913.0      1209.0
# 2         2.0          1.0         4.0      1057.0         0.0
# 3         3.0          1.0         4.0       744.0       700.0
# 4         2.0          1.0         4.0       831.0       614.0
#
#    Low Qual Fin SF  Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  \
# 0     8.881784e-16             0.0             0.0        2.0        1.0
# 1     8.881784e-16             1.0             0.0        2.0        1.0
# 2     8.881784e-16             1.0             0.0        1.0        0.0
# 3     8.881784e-16             0.0             0.0        2.0        1.0
# 4     8.881784e-16             0.0             0.0        2.0        0.0
#
#    Bedroom AbvGr  Kitchen AbvGr  Kitchen Qual  Functional  Garage Type  \
# 0            3.0            1.0           3.0         7.0          1.0
# 1            4.0            1.0           3.0         7.0          1.0
# 2            3.0            1.0           3.0         7.0          5.0
# 3            3.0            1.0           2.0         7.0          3.0
# 4            3.0            1.0           2.0         7.0          5.0
#
#    Garage Finish  Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 0            2.0          2.0           0.0           44.0             0.0
# 1            2.0          2.0           0.0           74.0             0.0
# 2            1.0          2.0           0.0           52.0             0.0
# 3            3.0          2.0         100.0            0.0             0.0
# 4            1.0          0.0           0.0           59.0             0.0
#
#      3Ssn Porch  Screen Porch  Fence  Misc Feature  Misc Val  Mo Sold  \
# 0 -4.440892e-16  3.552714e-15    0.0           1.0       0.0      3.0
# 1 -4.440892e-16  3.552714e-15    0.0           1.0       0.0      4.0
# 2 -4.440892e-16  3.552714e-15    0.0           1.0       0.0      1.0
# 3 -4.440892e-16  3.552714e-15    0.0           1.0       0.0      4.0
# 4 -4.440892e-16  3.552714e-15    0.0           1.0       0.0      3.0
#
#    Yr Sold  Sale Type  Exterior Combined  Rooms Combined  Fireplace Combined  \
# 0   2010.0        9.0               60.0          8874.0                 0.0
# 1   2009.0        9.0              196.0         16976.0                 3.0
# 2   2010.0        9.0              196.0          5285.0                 0.0
# 3   2010.0        9.0              196.0         10108.0                 0.0
# 4   2010.0        9.0              150.0          8670.0                 0.0
#
#    Garage Combined  Pool Combined  Bsmt Type 2 Combined  Year Combined  \
# 0           8550.0   8.881784e-16                   0.0      3904576.0
# 1          10062.0   8.881784e-16                   0.0      3986012.0
# 2           2214.0   8.881784e-16                   0.0      3814209.0
# 3           7200.0   8.881784e-16                   0.0      4026042.0
# 4           8712.0   8.881784e-16                   0.0      3718300.0
#
#    Year Combined Squared  Year Remod/Add Squared  SalePrice
# 0           1.524571e+13               4020025.0     130500
# 1           1.588829e+13               3988009.0     220000
# 2           1.454819e+13               4028049.0     109000
# 3           1.620901e+13               4028049.0     174000
# 4           1.382575e+13               3972049.0     138500

# %%
df_unscaled_unencoded = df_unscaled.copy()
all_columns_to_unscale = columns_to_label_encode.copy()
all_columns_to_unscale.remove("Exterior 1st")
all_columns_to_unscale.remove("Exterior 2nd")

for i in all_columns_to_unscale:
    df_unscaled_unencoded[i] = label_encoders_dict[i].inverse_transform(df_unscaled[i].astype(int).tolist())

# %%
df_unscaled_unencoded.head()
# Out:
#   MS SubClass MS Zoning  Lot Frontage  Lot Area  Street Alley Lot Shape  \
# 0          60        RL      61.89827   13517.0     1.0    NA       IR1
# 1          60        RL      43.00000   11492.0     1.0    NA       IR1
# 2          20        RL      68.00000    7922.0     1.0    NA       Reg
# 3          60        RL      73.00000    9802.0     1.0    NA       Reg
# 4          50        RL      82.00000   14235.0     1.0    NA       IR1
#
#   Land Contour  Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl        3.0     Corner        Gtl       Sawyer        RRAe
# 1          Lvl        3.0     Corner        Gtl      SawyerW        Norm
# 2          Lvl        3.0     Inside        Gtl        NAmes        Norm
# 3          Lvl        3.0     Inside        Gtl       Timber        Norm
# 4          Lvl        3.0     Inside        Gtl      SawyerW        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm      1Fam      2Story           6.0           8.0
# 1        Norm      1Fam      2Story           7.0           5.0
# 2        Norm      1Fam      1Story           5.0           7.0
# 3        Norm      1Fam      2Story           5.0           5.0
# 4        Norm      1Fam      1.5Fin           6.0           8.0
#
#    Year Remod/Add Roof Style Roof Matl Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 0          2005.0      Gable   CompShg      BrkFace         289.0         3.0
# 1          1997.0      Gable   CompShg      BrkFace         132.0         3.0
# 2          2007.0      Gable   CompShg         None           0.0         2.0
# 3          2007.0      Gable   CompShg         None           0.0         2.0
# 4          1993.0      Gable   CompShg         None           0.0         2.0
#
#    Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  BsmtFin Type 1  \
# 0         2.0     CBlock        3.0        3.0            1.0             6.0
# 1         2.0      PConc        4.0        3.0            1.0             6.0
# 2         3.0     CBlock        3.0        3.0            1.0             6.0
# 3         2.0      PConc        4.0        3.0            1.0             1.0
# 4         2.0      PConc        2.0        4.0            1.0             1.0
#
#    BsmtFin SF 1  Bsmt Unf SF  Total Bsmt SF Heating  Heating QC  Central Air  \
# 0         533.0        192.0          725.0    GasA         4.0          1.0
# 1         637.0        276.0          913.0    GasA         4.0          1.0
# 2         731.0        326.0         1057.0    GasA         2.0          1.0
# 3           0.0        384.0          384.0    GasA         3.0          1.0
# 4           0.0        676.0          676.0    GasA         2.0          1.0
#
#    Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Bsmt Full Bath  \
# 0         4.0       725.0       754.0     8.881784e-16             0.0
# 1         4.0       913.0      1209.0     8.881784e-16             1.0
# 2         4.0      1057.0         0.0     8.881784e-16             1.0
# 3         4.0       744.0       700.0     8.881784e-16             0.0
# 4         4.0       831.0       614.0     8.881784e-16             0.0
#
#    Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 0             0.0        2.0        1.0            3.0            1.0
# 1             0.0        2.0        1.0            4.0            1.0
# 2             0.0        1.0        0.0            3.0            1.0
# 3             0.0        2.0        1.0            3.0            1.0
# 4             0.0        2.0        0.0            3.0            1.0
#
#    Kitchen Qual  Functional Garage Type  Garage Finish  Paved Drive  \
# 0           3.0         7.0      Attchd            2.0          2.0
# 1           3.0         7.0      Attchd            2.0          2.0
# 2           3.0         7.0      Detchd            1.0          2.0
# 3           2.0         7.0     BuiltIn            3.0          2.0
# 4           2.0         7.0      Detchd            1.0          0.0
#
#    Wood Deck SF  Open Porch SF  Enclosed Porch    3Ssn Porch  Screen Porch  \
# 0           0.0           44.0             0.0 -4.440892e-16  3.552714e-15
# 1           0.0           74.0             0.0 -4.440892e-16  3.552714e-15
# 2           0.0           52.0             0.0 -4.440892e-16  3.552714e-15
# 3         100.0            0.0             0.0 -4.440892e-16  3.552714e-15
# 4           0.0           59.0             0.0 -4.440892e-16  3.552714e-15
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# 0    0.0           NA       0.0      3.0   2010.0       WD
# 1    0.0           NA       0.0      4.0   2009.0       WD
# 2    0.0           NA       0.0      1.0   2010.0       WD
# 3    0.0           NA       0.0      4.0   2010.0       WD
# 4    0.0           NA       0.0      3.0   2010.0       WD
#
#    Exterior Combined  Rooms Combined  Fireplace Combined  Garage Combined  \
# 0               60.0          8874.0                 0.0           8550.0
# 1              196.0         16976.0                 3.0          10062.0
# 2              196.0          5285.0                 0.0           2214.0
# 3              196.0         10108.0                 0.0           7200.0
# 4              150.0          8670.0                 0.0           8712.0
#
#    Pool Combined  Bsmt Type 2 Combined  Year Combined  Year Combined Squared  \
# 0   8.881784e-16                   0.0      3904576.0           1.524571e+13
# 1   8.881784e-16                   0.0      3986012.0           1.588829e+13
# 2   8.881784e-16                   0.0      3814209.0           1.454819e+13
# 3   8.881784e-16                   0.0      4026042.0           1.620901e+13
# 4   8.881784e-16                   0.0      3718300.0           1.382575e+13
#
#    Year Remod/Add Squared  SalePrice
# 0               4020025.0     130500
# 1               3988009.0     220000
# 2               4028049.0     109000
# 3               4028049.0     174000
# 4               3972049.0     138500

# %%
def scatter_plot_features_vs_target(df, x_columns, y_var):
    for i in x_columns:
        plt.figure(figsize = (15, 10))
        plt.scatter(df[i], df[y_var])
        plt.yticks(np.arange(0,700001,100000))
        plt.xlabel('Values of ' + str(i), fontsize = 15)
        plt.ylabel('Housing Price ($)', fontsize = 15)
        ax = plt.gca()
        ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
        plt.title('Housing Prices Based on ' + str(i))
        plt.show()

# %%
scatter_plot_features_vs_target(df_unscaled_unencoded, categorical_negative_correlation_columns, "SalePrice")

# %%
scatter_plot_features_vs_target(df_unscaled_unencoded, categorical_no_correlation_columns, "SalePrice")

# %%
for i in all_columns:
    print(df_unscaled_unencoded.groupby(i)['SalePrice'].mean())
# Out:
# Bldg Type
# 1Fam      185155.198937
# 2fmCon    123179.891304
# Duplex    139296.333333
# Twnhs     133100.000000
# TwnhsE    198312.372671
# Name: SalePrice, dtype: float64
# Land Contour
# Bnk    204590.672840
# Low    194913.756098
# Lvl    179013.814332
# Name: SalePrice, dtype: float64
# House Style
# 1.5Fin    135832.534562
# 1.5Unf    112466.666667
# 1Story    179630.764205
# 2.5Fin    243666.666667
# 2.5Unf    191785.714286
# 2Story    206579.951342
# SFoyer    149343.920000
# SLvl      166248.989362
# Name: SalePrice, dtype: float64
# Roof Matl
# CompShg    180755.004948
# Membran    241500.000000
# Tar&Grv    184088.142857
# WdShake    306000.000000
# Name: SalePrice, dtype: float64
# MS Zoning
# A (agr)     47300.000000
# C (all)     78010.894737
# FV         218618.316832
# I (all)     57625.000000
# RH         148859.571429
# RL         191104.170119
# RM         129049.968254
# Name: SalePrice, dtype: float64
# MS SubClass
# 120    211813.613636
# 150    148400.000000
# 160    138452.215909
# 180    109672.727273
# 190    124310.326087
# 20     189096.970013
# 30      94936.346535
# 40     119125.000000
# 45     116372.727273
# 50     136560.710660
# 60     239427.361323
# 70     153381.932584
# 75     204875.000000
# 80     169569.825581
# 85     154398.214286
# 90     139296.333333
# Name: SalePrice, dtype: float64
# Neighborhood
# Blmngtn    200417.681818
# Blueste    113258.000000
# BrkSide    127022.697368
# ClearCr    211729.280000
# CollgCr    202497.216667
# Crawfor    205901.211268
# Edwards    129905.787234
# Gilbert    189228.387931
# Greens     188666.666667
# GrnHill    280000.000000
# IDOTRR     100370.750000
# Landmrk    137000.000000
# MeadowV    100231.250000
# Mitchel    167656.707317
# NAmes      145594.831715
# NPkVill    140476.470588
# NWAmes     194619.022989
# NoRidge    316294.125000
# NridgHt    322831.352459
# OldTown    125276.300613
# SWISU      134758.875000
# Sawyer     137181.909910
# SawyerW    187760.160920
# Somerst    227183.900000
# StoneBr    329675.736842
# Timber     241051.354167
# Veenker    253570.588235
# Name: SalePrice, dtype: float64

# %%
def bar_chart_features_vs_target_means(df, x_columns, y_var):
    for i in x_columns:
        x_order = []
        [x_order.append(x) for x in df[i] if x not in x_order]
        ax = df.groupby(i)['SalePrice'].mean().loc[x_order].plot(kind = "bar", legend = False, figsize = (20,10))
        plt.xlabel('Values of ' + str(i), fontsize = 15)
        plt.ylabel('Average Price ($)', fontsize = 15)
        plt.yticks(np.arange(0,300001,100000))
        ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
        plt.title('Effect of ' + str(i) + ' on Price', fontsize = 25)
        plt.show()

# %%
bar_chart_features_vs_target_means(df_unscaled_unencoded, categorical_negative_correlation_columns, "SalePrice")

# %%
bar_chart_features_vs_target_means(df_unscaled_unencoded, categorical_no_correlation_columns, "SalePrice")

# %%
bar_chart_features_vs_target_means(df_unscaled_unencoded, ["Neighborhood"], "SalePrice")
